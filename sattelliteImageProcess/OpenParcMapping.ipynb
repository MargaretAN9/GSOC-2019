# %%
# See requirements.txt to set up your dev environment.
import os
import sys
import utm
import json
import scipy
import overpy
import urllib
import datetime 
import urllib3
import rasterio
import subprocess
import numpy as np
import pandas as pd
import seaborn as sns
from osgeo import gdal
from planet import api
from planet.api import filters
from traitlets import link
from rasterio.mask import mask
#import rasterio.tools.mask as rio_mask
from shapely.geometry import mapping, shape
from IPython.display import display, Image, HTML
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#from scipy import ndimage
import warnings
from osgeo import gdal


from osmapi import OsmApi
from geopy.geocoders import Nominatim

urllib3.disable_warnings()
from ipyleaflet import (
    Map,
    Marker,
    TileLayer, ImageOverlay,
    Polyline, Polygon, Rectangle, Circle, CircleMarker,
    GeoJSON,
    DrawControl
)

# %matplotlib inline
# will pick up api_key via environment variable PL_API_KEY
# but can be specified using `api_key` named argument
api_keys = json.load(open("apikeys.json",'r'))
client = api.ClientV1(api_key=api_keys["PLANET_API_KEY"])
gdal.UseExceptions()
api = overpy.Overpass()

# %%
# Basemap Mosaic (v1 API)
mosaicsSeries = 'global_quarterly_2017q1_mosaic'
# Planet tile server base URL (Planet Explorer Mosaics Tiles)
mosaicsTilesURL_base = 'https://tiles0.planet.com/experimental/mosaics/planet-tiles/' + mosaicsSeries + '/gmap/{z}/{x}/{y}.png'
# Planet tile server url
mosaicsTilesURL = mosaicsTilesURL_base + '?api_key=' + api_keys["PLANET_API_KEY"]
# Map Settings 
# Define colors
colors = {'blue': "#009da5"}
# Define initial map center lat/long
center = [52.96037, -1.164275]
# Define initial map zoom level
zoom = 13
# Set Map Tiles URL
planetMapTiles = TileLayer(url= mosaicsTilesURL)
# Create the map
m = Map(
    center=center, 
    zoom=zoom,
    default_tiles = planetMapTiles # Uncomment to use Planet.com basemap
)
# Define the draw tool type options
polygon = {'shapeOptions': {'color': colors['blue']}}
rectangle = {'shapeOptions': {'color': colors['blue']}} 

# Create the draw controls
# @see https://github.com/ellisonbg/ipyleaflet/blob/master/ipyleaflet/leaflet.py#L293
dc = DrawControl(
    polygon = polygon,
    rectangle = rectangle
)
# Initialize an action counter variable
actionCount = 0
AOIs = {}

# Register the draw controls handler
def handle_draw(self, action, geo_json):
    # Increment the action counter
    global actionCount
    actionCount += 1
    # Remove the `style` property from the GeoJSON
    geo_json['properties'] = {}
    # Convert geo_json output to a string and prettify (indent & replace ' with ")
    geojsonStr = json.dumps(geo_json, indent=2).replace("'", '"')
    AOIs[actionCount] = json.loads(geojsonStr)
    
# Attach the draw handler to the draw controls `on_draw` event
dc.on_draw(handle_draw)
m.add_control(dc)
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …

# %%
print(AOIs[1])
myAOI = AOIs[1]["geometry"]

# build a query using the AOI and
# a cloud_cover filter that excludes 'cloud free' scenes

old = datetime.datetime(year=2019,month=7,day=15)

query = filters.and_filter(
    filters.geom_filter(myAOI),
    filters.range_filter('cloud_cover', lt=5),
    filters.date_range('acquired', gt=old)
)

# build a request for only PlanetScope imagery
request = filters.build_search_request(
    query, item_types=['PSScene3Band']
)

# if you don't have an API key configured, this will raise an exception
result = client.quick_search(request)
scenes = []
planet_map = {}
for item in result.items_iter(limit=500):
    planet_map[item['id']]=item
    props = item['properties']
    props["id"] = item['id']
    props["geometry"] = item["geometry"]
    props["thumbnail"] = item["_links"]["thumbnail"]
    scenes.append(props)
scenes = pd.DataFrame(data=scenes)
# now let's clean up the datetime stuff
# make a shapely shape from our aoi
portland = shape(myAOI)
footprints = []
overlaps = []
# go through the geometry from our api call, convert to a shape and calculate overlap area.
# also save the shape for safe keeping
for footprint in scenes["geometry"].tolist():
    s = shape(footprint)
    footprints.append(s)
    overlap = 100.0*(portland.intersection(s).area / portland.area)
    overlaps.append(overlap)
# take our lists and add them back to our dataframe
scenes['overlap'] = pd.Series(overlaps, index=scenes.index)
scenes['footprint'] = pd.Series(footprints, index=scenes.index)
# now make sure pandas knows about our date/time columns.
scenes["acquired"] = pd.to_datetime(scenes["acquired"])
scenes["published"] = pd.to_datetime(scenes["published"])
scenes["updated"] = pd.to_datetime(scenes["updated"])

scenes = scenes[scenes['overlap']>0.9]


print(len(scenes))
# now let's clean up the datetime stuff
# make a shapely shape from our aoi
portland = shape(myAOI)
footprints = []
overlaps = []
# go through the geometry from our api call, convert to a shape and calculate overlap area.
# also save the shape for safe keeping
for footprint in scenes["geometry"].tolist():
    s = shape(footprint)
    footprints.append(s)
    overlap = 100.0*(portland.intersection(s).area / portland.area)
    overlaps.append(overlap)
# take our lists and add them back to our dataframe
scenes['overlap'] = pd.Series(overlaps, index=scenes.index)
scenes['footprint'] = pd.Series(footprints, index=scenes.index)
# now make sure pandas knows about our date/time columns.
scenes["acquired"] = pd.to_datetime(scenes["acquired"])
scenes["published"] = pd.to_datetime(scenes["published"])
scenes["updated"] = pd.to_datetime(scenes["updated"])

# first create a list of colors
colors = ["#ff0000","#00ff00","#0000ff","#ffff00","#ff00ff","#00ffff"]
# grab our scenes from the geometry/footprint geojson
footprints = scenes["geometry"].tolist()
# for each footprint/color combo

for footprint,color in zip(footprints,colors):
    # create the leaflet object
    feat = {'geometry':footprint,"properties":{
            'style':{'color': color,'fillColor': color,'fillOpacity': 0.1,'weight': 1}},
            'type':u"Feature"}
    # convert to geojson
    gjson = GeoJSON(data=feat)
    # add it our map
    m.add_layer(gjson)
# now we will draw our original AOI on top 
feat = {'geometry':myAOI,"properties":{
            'style':{'color': "#FFFFFF",'fillColor': "#FFFFFF",'fillOpacity': 0.1,'weight': 2}},
            'type':u"Feature"}
gjson = GeoJSON(data=feat)
m.add_layer(gjson)   
m
# Out:
# {'type': 'Feature', 'properties': {}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-1.160367, 52.9508], [-1.160367, 52.960038], [-1.131578, 52.960038], [-1.131578, 52.9508], [-1.160367, 52.9508]]]}}
# 9
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …

# %%
def get_products(client, scene_id, asset_type='PSScene3Band'):    
    """
    Ask the client to return the available products for a 
    given scene and asset type. Returns a list of product 
    strings
    """
    out = client.get_assets_by_id(asset_type,scene_id)
    temp = out.get()
    return temp.keys()

def activate_product(client, scene_id, asset_type="PSScene3Band",product="analytic"):
    """
    Activate a product given a scene, an asset type, and a product.
    
    On success return the return value of the API call and an activation object
    """
    temp = client.get_assets_by_id(asset_type,scene_id)  
    products = temp.get()
    if( product in products.keys() ):
        return client.activate(products[product]),products[product]
    else:
        return None 

def download_and_save(client,product):
    """
    Given a client and a product activation object download the asset. 
    This will save the tiff file in the local directory and return its 
    file name. 
    """
    out = client.download(product)
    fp = out.get_body()
    fp.write()
    return fp.name

def scenes_are_active(scene_list):
    """
    Check if all of the resources in a given list of
    scene activation objects is read for downloading.
    """
    retVal = True
    for scene in scene_list:
        if scene["status"] != "active":
            print("{} is not ready.".format(scene))
            return False
    return True

# %%
to_get = scenes["id"][0:7].tolist()
activated = []
# for each scene to get
for scene in to_get:
    # get the product 
    product_types = get_products(client,scene)
    for p in product_types:
        # if there is a visual product
        if p == "visual": # p == "basic_analytic_dn"
            print("Activating {0} for scene {1}".format(p,scene))
            # activate the product
            _,product = activate_product(client,scene,product=p)
            activated.append(product)
# Out:
# Activating visual for scene 20190721_104808_103d
# Activating visual for scene 20190721_104809_103d
# Activating visual for scene 20190721_090852_1053
# Activating visual for scene 20190720_103952_0e2f
# Activating visual for scene 20190717_104752_103d
# Activating visual for scene 20190717_104751_103d
# Activating visual for scene 20190717_090742_0f24

# %%
tiff_files = []
asset_type = "_3B_Visual"
# check if our scenes have been activated
if True:#scenes_are_active(activated):
    for to_download,name in zip(activated,to_get):
        # create the product name
        name = name + asset_type + ".tif"
        # if the product exists locally
        if( os.path.isfile(name) ):
            # do nothing 
            print ("We have scene {0} already, skipping...".format(name))
            tiff_files.append(name)
        elif to_download["status"] == "active":
            # otherwise download the product
            print("Downloading {0}....".format(name))
            fname = download_and_save(client,to_download)
            tiff_files.append(fname)
            print("Download done.")
        else:
            print("Could not download, still activating")
else:
    print ("Scenes aren't ready yet")

sorted(tiff_files)
print(tiff_files)
# Out:
# We have scene 20190721_104808_103d_3B_Visual.tif already, skipping...
# We have scene 20190721_104809_103d_3B_Visual.tif already, skipping...
# We have scene 20190721_090852_1053_3B_Visual.tif already, skipping...
# We have scene 20190720_103952_0e2f_3B_Visual.tif already, skipping...
# We have scene 20190717_104752_103d_3B_Visual.tif already, skipping...
# We have scene 20190717_104751_103d_3B_Visual.tif already, skipping...
# We have scene 20190717_090742_0f24_3B_Visual.tif already, skipping...
# ['20190721_104808_103d_3B_Visual.tif', '20190721_104809_103d_3B_Visual.tif', '20190721_090852_1053_3B_Visual.tif', '20190720_103952_0e2f_3B_Visual.tif', '20190717_104752_103d_3B_Visual.tif', '20190717_104751_103d_3B_Visual.tif', '20190717_090742_0f24_3B_Visual.tif']

# %%
infile = tiff_files[0]
# Open the file
gtif = gdal.Open(infile)
# Get the project reference object this knows the UTM zone
reff = gtif.GetProjectionRef()
# arr is the actual image data.
arr = gtif.ReadAsArray()
# Trans is our geo transfrom array. 
trans = gtif.GetGeoTransform()
# print the ref object
print(reff)
# find our UTM zone
i = reff.find("UTM")
print(reff[i:i+12])
# Out:
# PROJCS["WGS 84 / UTM zone 30N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-3],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32630"]]
# UTM zone 30N

# %%
def pixel2utm(ds, x, y):
    """
    Returns utm coordinates from pixel x, y coords
    """
    xoff, a, b, yoff, d, e = ds.GetGeoTransform()
    xp = a * x + b * y + xoff
    yp = d * x + e * y + yoff
    return(xp, yp)

def draw_point(x,y,img):
    t = 20
    # a cloud_cover filter that ex
    img[y-t:y+t,x-t:x+t,:] = [255,0,0]

# %%
pos = [7000,1400] # this is the pixel we want info abou
ds = gdal.Open(infile)
# take the GDAL info and make it into UTM
my_utm = pixel2utm(ds,pos[0],pos[1])
# convert UTM into Lat Long
# need to figure out how to get zone info
my_lla = utm.to_latlon(my_utm[0],my_utm[1],30,"N")
# do the lat long look up from OSM
geolocator = Nominatim()
# reverse look up the are based on lat lon
location = geolocator.reverse("{0},{1}".format(my_lla[0],my_lla[1]))
# print location info
print(location.address)
print(location.raw)
# get the OSM ID info
osm_id = int(location.raw["place_id"])
print(osm_id)
# create an interface to the OSM API
MyApi = OsmApi()
# Look up our position 
print(MyApi.NodeGet(osm_id))
# Out:
# C:\Users\mn271\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   if __name__ == '__main__':
# Arch Hill, Arnold and Carlton, Gedling, Nottinghamshire, East Midlands, England, NG5 8PF, UK
# {'place_id': 86903387, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 41989327, 'lat': '53.0186197826962', 'lon': '-1.13089687555374', 'display_name': 'Arch Hill, Arnold and Carlton, Gedling, Nottinghamshire, East Midlands, England, NG5 8PF, UK', 'address': {'road': 'Arch Hill', 'suburb': 'Arnold and Carlton', 'city': 'Gedling', 'town': 'Nottinghamshire', 'state_district': 'East Midlands', 'state': 'England', 'postcode': 'NG5 8PF', 'country': 'UK', 'country_code': 'gb'}, 'boundingbox': ['53.0156665', '53.0197164', '-1.1316121', '-1.1307749']}
# 86903387
# {'id': 86903387, 'visible': True, 'version': 2, 'changeset': 3391253, 'timestamp': datetime.datetime(2009, 12, 17, 5, 8, 25), 'user': 'woodpeck_fixbot', 'uid': 147510, 'lat': 39.456382, 'lon': -123.390688, 'tag': {}}

# %%
from matplotlib.patches import Circle
fig,ax = plt.subplots(1)

# create our plot
plt.imshow(arr[:3,:,:].transpose((1, 2, 0)))#, extent=extent)
fig = plt.gcf()
# add our annotation
plt.annotate(location.address, xy=pos, xycoords='data',
             xytext=(0.25, 0.5), textcoords='figure fraction',color="red",
             arrowprops=dict(arrowstyle="->"))
ax.set_aspect('equal')
# Set a point
circ = Circle((pos[0],pos[1]),60,color="red")
ax.add_patch(circ)
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
import geopandas as gpd
fname = "./nottinghamUK.geojson"
park_df = gpd.read_file(fname)
portland_parks = json.load(open(fname,'r'))
# raw geojson works better with GDAL
geojson = [p for p in portland_parks["features"]]
# no area out of the box
p = [p.area for p in park_df["geometry"].tolist()]
park_df["area"] = pd.Series(p)
park_df["geojson"] = pd.Series(geojson)
park_df.sort_values(['area',], ascending=[1])
park_df.head()
#len(park_df)
#print park_df["wikipedia"].dropna()
# Out:
#                 id              @id boundary   designation leisure  \
# 0  relation/551350  relation/551350  reserve  country_park    park
# 1     way/12342743     way/12342743     None          None    park
# 2     way/12342805     way/12342805     None          None    park
# 3     way/12343241     way/12343241     None          None    park
# 4     way/12345070     way/12345070     None          None    park
#
#                                 name          type   HE_ref  \
# 0              Cotgrave Country Park  multipolygon     None
# 1                    Highfields Park          None  1001350
# 2  Leyton Crescent Recreation Ground          None     None
# 3                     Melbourne Park          None     None
# 4                     Broadgate Park          None     None
#
#                                        is_in  is_in:city  ... glass_bottles  \
# 0                                       None        None  ...          None
# 1  Nottingham,Nottinghamshire,United Kingdom  Nottingham  ...          None
# 2     Beeston,Nottinghamshire,United Kingdom        None  ...          None
# 3                                       None        None  ...          None
# 4     Beeston,Nottinghamshire,United Kingdom        None  ...          None
#
#   opening_hours confetti description old_operator old_use start_date  \
# 0          None     None        None         None    None       None
# 1          None     None        None         None    None       None
# 2          None     None        None         None    None       None
# 3          None     None        None         None    None       None
# 4          None     None        None         None    None       None
#
#                                             geometry      area  \
# 0  POLYGON ((-1.0416941 52.9179725, -1.041696 52....  0.000091
# 1  POLYGON ((-1.1887554 52.9371657, -1.1887225 52...  0.000028
# 2  POLYGON ((-1.1953624 52.9173489, -1.195336 52....  0.000005
# 3  POLYGON ((-1.1896346 52.9698269, -1.1895718 52...  0.000019
# 4  POLYGON ((-1.2115256 52.929064, -1.2114785 52....  0.000002
#
#                                              geojson
# 0  {'type': 'Feature', 'properties': {'@id': 'rel...
# 1  {'type': 'Feature', 'properties': {'@id': 'way...
# 2  {'type': 'Feature', 'properties': {'@id': 'way...
# 3  {'type': 'Feature', 'properties': {'@id': 'way...
# 4  {'type': 'Feature', 'properties': {'@id': 'way...
#
# [5 rows x 62 columns]

# %%
for p in portland_parks["features"]:
    feat = {'geometry':p["geometry"],"properties":{
            'style':{'color': "#00FF00",'fillColor': "#00FF00",'fillOpacity': 0.0,'weight': 1}},
            'type':u"Feature"}
    # convert to geojson
    gjson = GeoJSON(data=feat)
    # add it our map
    m.add_layer(gjson)
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …

# %%
park_sz = park_df.groupby("name").sum() 
park_sz = park_sz.sort_values(by='area',ascending=[0])
display(park_sz)
# Out:
#                                                        area
# name
# Wollaton Park                                  2.773131e-04
# Holme Pierrepont Country Park                  1.757633e-04
# University of Nottingham                       1.571863e-04
# Gedling Country Park                           1.291217e-04
# Colwick Country Park                           1.163415e-04
# Cotgrave Country Park                          9.096942e-05
# Broxtowe Country Park                          5.805690e-05
# Phoenix Park                                   5.671984e-05
# Bramcote Hills Park                            4.052495e-05
# Southglade Park                                3.661619e-05
# Forest Recreation Ground                       3.234125e-05
# Woodthorpe Grange Park                         2.904474e-05
# Highfields Park                                2.787600e-05
# Melbourne Park                                 1.893474e-05
# Trent Meadows                                  1.576350e-05
# Lambley Lane Recreation Ground (North)         1.515697e-05
# Arnot Hill Park                                1.179296e-05
# Hemlock Stone Open Space                       1.138821e-05
# Vernon Park                                    1.134216e-05
# Grange Park                                    1.129862e-05
# Arboretum                                      9.786135e-06
# Bridgford Park                                 9.048868e-06
# Clifton Central 'Flower' Park                  8.118053e-06
# Coppice Park                                   8.097682e-06
# Inham Nook Recreation Ground                   7.957474e-06
# Digby Park                                     7.745163e-06
# Colwick Rectory Recreation Ground              7.231554e-06
# Sycamore Park                                  6.487614e-06
# Weirfield Recreation Ground                    5.914098e-06
# Burton Road Jubilee Park                       5.758315e-06
# ...                                                     ...
# Locksley Park                                  3.911231e-07
# Pirate Park Play Area                          3.859111e-07
# Pearmain Park                                  3.727253e-07
# Wallan Street Playground                       3.658186e-07
# Bobbersmill Play Area                          3.585638e-07
# Breckswood Park                                3.385236e-07
# Forster Street Play Area                       3.326451e-07
# Mountfield Drive Open Space                    3.226560e-07
# John Farr Rest Garden                          3.012624e-07
# Lambourne Drive Childrens Playground           2.972792e-07
# Lincoln Circus                                 2.856956e-07
# Overstrand Close Open Space                    2.808949e-07
# Priory Sculpture Park                          2.626747e-07
# Peppers Gardens                                2.469125e-07
# The Square                                     2.119483e-07
# Grangewood Road Community Park                 1.728998e-07
# Willow Gardens                                 1.555216e-07
# Boulevard Gardens                              1.408890e-07
# Silverdale Road Open Space                     1.356575e-07
# Bellar Gate Rest Garden                        1.337418e-07
# Hedley Villas Park                             1.241539e-07
# Burton Road Public Garden                      1.131600e-07
# Peveril Gardens                                1.098302e-07
# Poplar Avenue Playground                       1.068088e-07
# Friends Burial Ground                          1.059077e-07
# Edison Way Square                              8.162408e-08
# The Bay of Biscay                              7.658836e-08
# Nottingham Register Office Photography Garden  6.607296e-08
# The Kieron Hill Clifton War Memorial Garden    6.431253e-08
# Owen's Place                                   6.261605e-08
#
# [130 rows x 1 columns]

# %%
def write_geojson_by_name(df,name,outfile):
    """
    Take in a dataframe, a park name, and an output file name 
    Save the park's geojson to the specified file.
    """
    temp = df[df["name"]==name]
    to_write = {"type": "FeatureCollection",
                "features": temp["geojson"].tolist()}
    with open(outfile,'w') as fp:
        fp.write(json.dumps(to_write))
def crop_scenes_to_geojson(geojson,scenes,out_name):
    """
    Take in a geojson file, a list of scenes, and an output name
    Call gdal and warp the scenes to match the geojson file and save the results to outname.
    """
    commands = ["gdalwarp", # t
           "-t_srs","EPSG:3857",
           "-cutline",geojson,
           "-crop_to_cutline",
           "-tap",
            "-tr", "3", "3"
           "-overwrite"]
    for tiff in scenes:
        commands.append(tiff)
    commands.append(out_name)
    print(" ".join(commands))
    subprocess.call(commands)

# %%
geo_json_files = []
tif_file_names = []
unique_park_names = list(set(park_df["name"].tolist()))
for name in list(unique_park_names):
    # Generate our file names 
    #print(name)
    if name is not None:
        
        geojson_name = "./parks/"+ name.replace(" ","_") +".geojson"
        tif_name = "./parks/"+name.replace(" ","_")+".tif"
        # write geojson
        write_geojson_by_name(park_df,name,geojson_name)
        # write to park file
        crop_scenes_to_geojson(geojson_name,tiff_files,tif_name)
        # Save the results to lists
        geo_json_files.append(geojson_name)
        tif_file_names.append(tif_name)
# Out:
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Memorial_Gardens.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Memorial_Gardens.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Ruddington_Lane_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Ruddington_Lane_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Dunkirk_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Dunkirk_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Strelley_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Strelley_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Victoria_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Victoria_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/King_George's_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/King_George's_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Gawthorne_Street_Playground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Gawthorne_Street_Playground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Grange_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Grange_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Pearmain_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Pearmain_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Miss_Machin's_Field.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Miss_Machin's_Field.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Peppers_Gardens.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Peppers_Gardens.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Nottingham_Castle_Grounds.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Nottingham_Castle_Grounds.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Inham_Nook_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Inham_Nook_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Mosswood_Crescent_Open_Space.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Mosswood_Crescent_Open_Space.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Silverdale_Road_Open_Space.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Silverdale_Road_Open_Space.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Cotgrave_Country_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Cotgrave_Country_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Weirfield_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Weirfield_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Edison_Way_Square.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Edison_Way_Square.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/The_Square.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/The_Square.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Grangewood_Road_Community_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Grangewood_Road_Community_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Angell_Green_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Angell_Green_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Leyton_Crescent_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Leyton_Crescent_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Colesbourne_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Colesbourne_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Lincoln_Circus.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Lincoln_Circus.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Shipstone_Street_Play_Area.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Shipstone_Street_Play_Area.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Nottingham_Register_Office_Photography_Garden.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Nottingham_Register_Office_Photography_Garden.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Independent_Street_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Independent_Street_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Newcastle_Circus.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Newcastle_Circus.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Woodthorpe_Grange_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Woodthorpe_Grange_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/The_Cliffs.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/The_Cliffs.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Hedley_Villas_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Hedley_Villas_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Fearnleigh_Play_Area.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Fearnleigh_Play_Area.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Arboretum.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Arboretum.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Forster_Street_Play_Area.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Forster_Street_Play_Area.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Stockhill_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Stockhill_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Bramcote_Lane_Open_Space.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Bramcote_Lane_Open_Space.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Arnot_Hill_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Arnot_Hill_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Forest_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Forest_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Phoenix_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Phoenix_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Holme_Pierrepont_Country_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Holme_Pierrepont_Country_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Bellar_Gate_Rest_Garden.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Bellar_Gate_Rest_Garden.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Watnall_Green.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Watnall_Green.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Cator_Lane_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Cator_Lane_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Basil_Russell_Playing_Fields.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Basil_Russell_Playing_Fields.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/St._Mary's_Rest_Garden.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/St._Mary's_Rest_Garden.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Gedling_Country_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Gedling_Country_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Lenton_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Lenton_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Robin_Hood_Chase_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Robin_Hood_Chase_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Roberts_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Roberts_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Southglade_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Southglade_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Millennium_Garden.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Millennium_Garden.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Lambley_Lane_Recreation_Ground_(South).geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Lambley_Lane_Recreation_Ground_(South).tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Hemlock_Stone_Open_Space.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Hemlock_Stone_Open_Space.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Rocket_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Rocket_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Highfields_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Highfields_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Valley_Road_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Valley_Road_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Broxtowe_Country_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Broxtowe_Country_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Colwick_Country_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Colwick_Country_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/John_Farr_Rest_Garden.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/John_Farr_Rest_Garden.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Willow_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Willow_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Barton_Green_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Barton_Green_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Overstrand_Close_Open_Space.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Overstrand_Close_Open_Space.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Ring_Leas_Play_Area.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Ring_Leas_Play_Area.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Wollaton_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Wollaton_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Colwick_Rectory_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Colwick_Rectory_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Broadgate_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Broadgate_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Boulevard_Gardens.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Boulevard_Gardens.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Radford_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Radford_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Scaffell_Way_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Scaffell_Way_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Bridlington_Street_Playground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Bridlington_Street_Playground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Bramcote_Hills_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Bramcote_Hills_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Sycamore_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Sycamore_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Burton_Road_Jubilee_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Burton_Road_Jubilee_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/King_George_V_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/King_George_V_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/University_of_Nottingham.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/University_of_Nottingham.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Wilford_Green.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Wilford_Green.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Thackerays_Lane_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Thackerays_Lane_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/The_Willows_Open_Space.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/The_Willows_Open_Space.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Boundary_Road_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Boundary_Road_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Locksley_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Locksley_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Wallan_Street_Playground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Wallan_Street_Playground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/The_Bay_of_Biscay.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/The_Bay_of_Biscay.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Lenton_Abbey_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Lenton_Abbey_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Melbourne_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Melbourne_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Valley_Road_Water_Meadow.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Valley_Road_Water_Meadow.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Heathfield_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Heathfield_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Friends_Burial_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Friends_Burial_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Digby_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Digby_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Rushford_Drive_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Rushford_Drive_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/The_Kieron_Hill_Clifton_War_Memorial_Garden.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/The_Kieron_Hill_Clifton_War_Memorial_Garden.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Rockley_Memorial_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Rockley_Memorial_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Tricket's_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Tricket's_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Sandpiper_Way_Open_Space.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Sandpiper_Way_Open_Space.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Eastcote_Avenue_Open_Space.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Eastcote_Avenue_Open_Space.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Valley_Road_Park_-_The_Jason_Spencer_Sports_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Valley_Road_Park_-_The_Jason_Spencer_Sports_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Heskey_Park_&_Play_Area.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Heskey_Park_&_Play_Area.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Lambley_Lane_Recreation_Ground_(North).geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Lambley_Lane_Recreation_Ground_(North).tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Trent_Meadows.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Trent_Meadows.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Dovecote_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Dovecote_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Vernon_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Vernon_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Redbridge_Drive_Open_Space.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Redbridge_Drive_Open_Space.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Lambourne_Drive_Childrens_Playground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Lambourne_Drive_Childrens_Playground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Poplar_Avenue_Playground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Poplar_Avenue_Playground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Owen's_Place.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Owen's_Place.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Brewhouse_Yard.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Brewhouse_Yard.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Mountfield_Drive_Open_Space.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Mountfield_Drive_Open_Space.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Woodfield_Road_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Woodfield_Road_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Pirate_Park_Play_Area.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Pirate_Park_Play_Area.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Bulwell_Bogs.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Bulwell_Bogs.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Queen's_Walk_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Queen's_Walk_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Parkdale_Playground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Parkdale_Playground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Peggy's_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Peggy's_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/St_Peter's_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/St_Peter's_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Priory_Sculpture_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Priory_Sculpture_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Sunninghill_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Sunninghill_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Moor_Road_Open_Space.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Moor_Road_Open_Space.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Ambleside_Play_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Ambleside_Play_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Coppice_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Coppice_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Conway_Road_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Conway_Road_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Breckswood_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Breckswood_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Peveril_Gardens.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Peveril_Gardens.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Burton_Road_Public_Garden.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Burton_Road_Public_Garden.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Bobbersmill_Play_Area.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Bobbersmill_Play_Area.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Clifton_Central_'Flower'_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Clifton_Central_'Flower'_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Salop_Street_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Salop_Street_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/King_Edward_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/King_Edward_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Ashton_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Ashton_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Bridgford_Park.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Bridgford_Park.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Chetwynd_Road_Recreation_Ground.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Chetwynd_Road_Recreation_Ground.tif
# gdalwarp -t_srs EPSG:3857 -cutline ./parks/Willow_Gardens.geojson -crop_to_cutline -tap -tr 3 3-overwrite 20190721_104808_103d_3B_Visual.tif 20190721_104809_103d_3B_Visual.tif 20190721_090852_1053_3B_Visual.tif 20190720_103952_0e2f_3B_Visual.tif 20190717_104752_103d_3B_Visual.tif 20190717_104751_103d_3B_Visual.tif 20190717_090742_0f24_3B_Visual.tif ./parks/Willow_Gardens.tif

# %%
#magic = ["mogrify","-format", "jpg", "./parks/*.tif"]
#subprocess.call(magic)
#for p in tif_file_names[0:20]:
#    print(p)
#    display(Image(p.replace('tif','jpg')))

# %%
def load_image3(filename):
    """Return a 3D (r, g, b) numpy array with the data in the specified TIFF filename."""
    path = os.path.abspath(os.path.join('./', filename))
    if os.path.exists(path):
        with rasterio.open(path) as src:
            b,g,r,mask = src.read()
            return np.dstack([b, g, r])
        

def get_avg_greeness(filename):
    retVal = -1.0
    try:
        # load the image
        img = load_image3(filename)
        if img is not None:
            # add all the channels together, black pixels will still be zero
            # this isn't a perfect method but there are very few truly black spots 
            # on eart
            black_like_my_soul = np.add(np.add(img[:,:,0],img[:,:,1]),img[:,:,2])
            # sum up the not black pixels
            not_black = np.count_nonzero(black_like_my_soul)
            # sum up all the green
            img = np.array(img,dtype='int16')
            total_green = np.sum(img[:,:,1]-((np.add(img[:,:,0],img[:,:,2])/2)))
            # calculate our metric
            if total_green != 0 and not_black > 0:
                retVal = total_green / float(not_black)
        return retVal
    except Exception as e:
        print (e)
        return -1.0

# %%
greens = [get_avg_greeness(f) for f in tif_file_names]
print(greens)
# Out:
# [0.03874291602266873, 0.2949226243765187, 0.7015463917525773, 4.198844672657253, 4.27434554973822, 2.2523181853015557, 3.9634847613571016, 0.1358695652173913, -1.0, -1.0, 0.17446043165467626, -1.0, 3.513851257948576, 0.6907441433164906, 0.8592233009708737, 5.96312525896875, 0.5665455623934159, 5.531914893617022, -1.0, 1.8885941644562334, 1.1601478287650138, -0.37368471860218166, -0.15027977617905675, -1.0, -0.9419689119170984, 0.6286764705882353, 0.5477983777520278, -1.0, 0.10504720461355457, 4.33311170212766, -1.0, 0.8417792792792793, 0.28004287053990085, 0.6051248357424441, -0.9912579770959, 0.2179345828739434, 0.42089840127601175, -0.5937521130570018, 0.6487512734232704, 0.42805584327629825, -1.0, 4.682115690783655, 0.6949331456720619, 2.227504553734062, 0.6808303886925795, 0.3724908535243968, -0.00026680896478121667, -0.006114130434782609, 5.135258358662614, -0.42661989811136164, -0.04290853031860226, 0.000978633175664655, 3.167677391942524, 0.5619006102877071, 0.7850030625225762, 0.6488946684005201, 2.767287928932242, 0.08715244342802118, -0.6056547619047619, 0.17486590038314176, 6.370166614272241, -1.0, 5.065586419753086, 1.5003605125458366, -1.0, -0.17295459530598817, -0.3665644171779141, 0.019327842720510097, 1.681210415200563, 0.3246753246753247, 1.844721876184802, -0.009645217860515311, 0.6005699088145897, 0.0032646911099949772, 0.4966344934459721, -1.0, 0.10867555790307672, 0.3786046511627907, 0.7628113879003559, 1.6872171945701357, -0.5533175355450237, -1.0, 1.1908484709128535, 4.445436485019289, 0.1464172756025739, -0.9410760034158838, 0.495850622406639, 0.04170899650073372, -0.16327433628318583, 1.2328767123287672, 6.156400113026279, -1.0, -0.0032258064516129032, 2.0337941628264207, -0.4331750827219105, -0.060625, 0.030175398107546735, 1.0239632759637252, -0.8348684210526316, 1.004702798550613, 3.2767857142857144, -0.7645348837209303, -1.0, 1.3523489932885906, -1.0, 0.8269230769230769, 1.831345326554556, -0.6610925306577481, 0.5904317386231038, -1.0, -1.0, -0.01270891364902507, 0.38447088290544773, -0.10135135135135136, 0.2074468085106383, 4.5234657039711195, 0.4751924721984602, 0.0725005398402073, 0.7754932255764202, 0.8016688061617459, -1.0, -1.0, 4.150314465408805, 0.9472007774118664, -1.0, 0.785095613048369, 1.0601436265709157, 4.649477806788512, 0.660394982652789, -1.0]

# %%
paired = list(zip(tif_file_names,greens))
paired.sort(key=lambda tup: tup[1])
#sorted(paired, key=lambda tup: tup[1])
paired.reverse()
labels = [p[0][8:-4].replace("_"," ") for p in paired]
data = [p[1] for p in paired]
plt.figure(figsize=(20,6))
xlocations = np.array(range(len(paired)))+0.5
width = 1
plt.bar(xlocations, data, width=width)
plt.yticks(range(-1,25,1))
plt.xticks(xlocations+ width/2, labels)
plt.xlim(0, xlocations[-1]+width*2)
plt.ylim(-2,np.max(data)+1)
plt.title("Greeness over Average Red and Blue Per Park")
plt.gca().get_xaxis().tick_bottom()
plt.gca().get_yaxis().tick_left()
xa = plt.gca()
xa.set_xticklabels(xa.xaxis.get_majorticklabels(), rotation=90)
plt.show()

# %%
imgs = [p[0] for p in paired]
for p in imgs:
    print (p[8:-4].replace("_"," "))
   # display(Image(p.replace('tif','jpg')))
# Out:
# Barton Green Park
# Rockley Memorial Park
# Cotgrave Country Park
# Edison Way Square
# Roberts Recreation Ground
# Ring Leas Play Area
# Watnall Green
# Bridgford Park
# Moor Road Open Space
# Melbourne Park
# The Cliffs
# Victoria Park
# Strelley Recreation Ground
# Bobbersmill Play Area
# Gawthorne Street Playground
# Inham Nook Recreation Ground
# Redbridge Drive Open Space
# Hemlock Stone Open Space
# Broxtowe Country Park
# King George's Park
# Basil Russell Playing Fields
# Eastcote Avenue Open Space
# Grangewood Road Community Park
# Bramcote Hills Park
# Woodfield Road Recreation Ground
# Locksley Park
# Scaffell Way Park
# Wollaton Park
# Owen's Place
# The Kieron Hill Clifton War Memorial Garden
# Lenton Abbey Park
# Angell Green Park
# Ashton Park
# Trent Meadows
# Vernon Park
# Clifton Central 'Flower' Park
# Silverdale Road Open Space
# Fearnleigh Play Area
# Mountfield Drive Open Space
# Breckswood Park
# King Edward Park
# Highfields Park
# Conway Road Recreation Ground
# Boundary Road Park
# Dunkirk Park
# Cator Lane Recreation Ground
# Mosswood Crescent Open Space
# St. Mary's Rest Garden
# Chetwynd Road Recreation Ground
# Valley Road Park
# Phoenix Park
# Nottingham Register Office Photography Garden
# Forster Street Play Area
# Burton Road Jubilee Park
# Bulwell Bogs
# Weirfield Recreation Ground
# Rocket Park
# Independent Street Park
# University of Nottingham
# Friends Burial Ground
# Ambleside Play Park
# Holme Pierrepont Country Park
# Arnot Hill Park
# St Peter's Park
# The Willows Open Space
# Gedling Country Park
# Bridlington Street Playground
# Ruddington Lane Recreation Ground
# Arboretum
# Bramcote Lane Open Space
# Sunninghill Park
# Willow Park
# Peppers Gardens
# Valley Road Water Meadow
# Grange Park
# Thackerays Lane Recreation Ground
# Woodthorpe Grange Park
# Colwick Country Park
# Coppice Park
# Digby Park
# Memorial Gardens
# Lambley Lane Recreation Ground (North)
# Radford Recreation Ground
# King George V Recreation Ground
# Lambley Lane Recreation Ground (South)
# Lenton Recreation Ground
# Sandpiper Way Open Space
# Robin Hood Chase Park
# Sycamore Park
# Peggy's Park
# Millennium Garden
# Heskey Park & Play Area
# Priory Sculpture Park
# Colesbourne Park
# Rushford Drive Park
# Broadgate Park
# Boulevard Gardens
# Leyton Crescent Recreation Ground
# Southglade Park
# Valley Road Park - The Jason Spencer Sports Ground
# Wallan Street Playground
# Forest Recreation Ground
# John Farr Rest Garden
# Pirate Park Play Area
# Lambourne Drive Childrens Playground
# Dovecote Park
# Heathfield Park
# Shipstone Street Play Area
# Stockhill Park
# Willow Gardens
# Salop Street Park
# Burton Road Public Garden
# Peveril Gardens
# Parkdale Playground
# Queen's Walk Recreation Ground
# Brewhouse Yard
# Poplar Avenue Playground
# Tricket's Park
# The Bay of Biscay
# Wilford Green
# Colwick Rectory Recreation Ground
# Overstrand Close Open Space
# Bellar Gate Rest Garden
# Hedley Villas Park
# Newcastle Circus
# Lincoln Circus
# The Square
# Nottingham Castle Grounds
# Miss Machin's Field
# Pearmain Park

# %%
opacity_map = {}
gmax = np.max(greens)
gmin = np.min(greens)
# this is a nonlinear mapping
opacity = [np.clip((float(g**2)-gmin)/float(gmax-gmin),0,3) for g in greens]
for op,name in zip(opacity,imgs):
    opacity_map[name]=op

m = Map(
    center=center, 
    zoom=zoom,
    default_tiles = planetMapTiles # Uncomment to use Planet.com basemap
)
dc = DrawControl(
    polygon = polygon,
    rectangle = rectangle
)
# Initialize an action counter variable
actionCount = 0
AOIs = {}

# Register the draw controls handler
def handle_draw(self, action, geo_json):
    # Increment the action counter
    global actionCount
    actionCount += 1
    # Remove the `style` property from the GeoJSON
    geo_json['properties'] = {}
    # Convert geo_json output to a string and prettify (indent & replace ' with ")
    geojsonStr = json.dumps(geo_json, indent=2).replace("'", '"')
    AOIs[actionCount] = json.loads(geojsonStr)
    
# Attach the draw handler to the draw controls `on_draw` event
dc.on_draw(handle_draw)
m.add_control(dc)
m

for p in portland_parks["features"]:
    if (p["properties"]) is not None and "name" in (p["properties"]) is not None:
        t = "./parks/"+p["properties"]["name"].replace(" ","_") + ".tif"
        feat = {'geometry':p["geometry"],"properties":{
                'style':{'color': "#00FF00",'fillColor': "#00FF00",'fillOpacity': opacity_map[t],'weight': 1}},
                'type':u"Feature"}
        # convert to geojson
        gjson = GeoJSON(data=feat)
        # add it our map
        m.add_layer(gjson)
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …
